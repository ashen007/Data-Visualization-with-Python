# %% [markdown]
# ### More Exercises

# %% [markdown]
# ### Indexing Numpy array

# %%
import numpy as np
dataset = np.genfromtxt('./data/normal_distribution.csv', delimiter=',')

# %%
dataset
# Out:
# array([[ 99.14931546, 104.03852715, 107.43534677,  97.85230675,
#          98.74986914,  98.80833412,  96.81964892,  98.56783189],
#        [ 92.02628776,  97.10439252,  99.32066924,  97.24584816,
#          92.9267508 ,  92.65657752, 105.7197853 , 101.23162942],
#        [ 95.66253664,  95.17750125,  90.93318132, 110.18889465,
#          98.80084371, 105.95297652,  98.37481387, 106.54654286],
#        [ 91.37294597, 100.96781394, 100.40118279, 113.42090475,
#         105.48508838,  91.6604946 , 106.1472841 ,  95.08715803],
#        [101.20862522, 103.5730309 , 100.28690912, 105.85269352,
#          93.37126331, 108.57980357, 100.79478953,  94.20019732],
#        [102.80387079,  98.29687616,  93.24376389,  97.24130034,
#          89.03452725,  96.2832753 , 104.60344836, 101.13442416],
#        [106.71751618, 102.97585605,  98.45723272, 100.72418901,
#         106.39798503,  95.46493436,  94.35373179, 106.83273763],
#        [ 96.02548256, 102.82360856, 106.47551845, 101.34745901,
# ...

# %%
dataset[0]
# Out:
# array([ 99.14931546, 104.03852715, 107.43534677,  97.85230675,
#         98.74986914,  98.80833412,  96.81964892,  98.56783189])

# %%
dataset[-1]
# Out:
# array([ 94.11176915,  99.62387832, 104.51786419,  97.62787811,
#         93.97853495,  98.75108352, 106.05042487, 100.07721494])

# %%
dataset[0,0]
# Out:
# 99.14931546

# %%
dataset[-1,-1]
# Out:
# 100.07721494

# %% [markdown]
# ### slicing numpy multi-dimensional array

# %%
dataset[0:2]
# Out:
# array([[ 99.14931546, 104.03852715, 107.43534677,  97.85230675,
#          98.74986914,  98.80833412,  96.81964892,  98.56783189],
#        [ 92.02628776,  97.10439252,  99.32066924,  97.24584816,
#          92.9267508 ,  92.65657752, 105.7197853 , 101.23162942]])

# %%
dataset[:,0:2]
# Out:
# array([[ 99.14931546, 104.03852715],
#        [ 92.02628776,  97.10439252],
#        [ 95.66253664,  95.17750125],
#        [ 91.37294597, 100.96781394],
#        [101.20862522, 103.5730309 ],
#        [102.80387079,  98.29687616],
#        [106.71751618, 102.97585605],
#        [ 96.02548256, 102.82360856],
#        [105.30350449,  92.87730812],
#        [110.44484313,  93.87155456],
#        [101.3514185 , 100.37372248],
#        [ 97.21315663, 107.02874163],
#        [ 95.65982034, 107.22482426],
#        [100.39303522,  92.0108226 ],
#        [103.1521596 , 109.40523174],
#        [106.11454989,  88.80221141],
#        [ 96.78266211,  99.84251605],
#        [101.86186193, 103.61720152],
#        [ 97.49594839,  96.59385486],
#        [ 96.76814836,  91.6779221 ],
#        [106.89005002, 106.57364584],
#        [ 99.80873105, 101.63973121],
#        [ 96.10020311,  94.57421727],
#        [ 94.11176915,  99.62387832]])

# %%
dataset[:2,:2]
# Out:
# array([[ 99.14931546, 104.03852715],
#        [ 92.02628776,  97.10439252]])

# %%
dataset[0,::-1]
# Out:
# array([ 98.56783189,  96.81964892,  98.80833412,  98.74986914,
#         97.85230675, 107.43534677, 104.03852715,  99.14931546])

# %%
dataset[0:5,:6:2]
# Out:
# array([[ 99.14931546, 107.43534677,  98.74986914],
#        [ 92.02628776,  99.32066924,  92.9267508 ],
#        [ 95.66253664,  90.93318132,  98.80084371],
#        [ 91.37294597, 100.40118279, 105.48508838],
#        [101.20862522, 100.28690912,  93.37126331]])

# %% [markdown]
# ### Splitting

# %%
subset = np.vsplit(dataset, 3)
subset[0]
# Out:
# array([[ 99.14931546, 104.03852715, 107.43534677,  97.85230675,
#          98.74986914,  98.80833412,  96.81964892,  98.56783189],
#        [ 92.02628776,  97.10439252,  99.32066924,  97.24584816,
#          92.9267508 ,  92.65657752, 105.7197853 , 101.23162942],
#        [ 95.66253664,  95.17750125,  90.93318132, 110.18889465,
#          98.80084371, 105.95297652,  98.37481387, 106.54654286],
#        [ 91.37294597, 100.96781394, 100.40118279, 113.42090475,
#         105.48508838,  91.6604946 , 106.1472841 ,  95.08715803],
#        [101.20862522, 103.5730309 , 100.28690912, 105.85269352,
#          93.37126331, 108.57980357, 100.79478953,  94.20019732],
#        [102.80387079,  98.29687616,  93.24376389,  97.24130034,
#          89.03452725,  96.2832753 , 104.60344836, 101.13442416],
#        [106.71751618, 102.97585605,  98.45723272, 100.72418901,
#         106.39798503,  95.46493436,  94.35373179, 106.83273763],
#        [ 96.02548256, 102.82360856, 106.47551845, 101.34745901,
# ...

# %%
subset = np.hsplit(dataset,4)
subset[0]
# Out:
# array([[ 99.14931546, 104.03852715],
#        [ 92.02628776,  97.10439252],
#        [ 95.66253664,  95.17750125],
#        [ 91.37294597, 100.96781394],
#        [101.20862522, 103.5730309 ],
#        [102.80387079,  98.29687616],
#        [106.71751618, 102.97585605],
#        [ 96.02548256, 102.82360856],
#        [105.30350449,  92.87730812],
#        [110.44484313,  93.87155456],
#        [101.3514185 , 100.37372248],
#        [ 97.21315663, 107.02874163],
#        [ 95.65982034, 107.22482426],
#        [100.39303522,  92.0108226 ],
#        [103.1521596 , 109.40523174],
#        [106.11454989,  88.80221141],
#        [ 96.78266211,  99.84251605],
#        [101.86186193, 103.61720152],
#        [ 97.49594839,  96.59385486],
#        [ 96.76814836,  91.6779221 ],
#        [106.89005002, 106.57364584],
#        [ 99.80873105, 101.63973121],
#        [ 96.10020311,  94.57421727],
#        [ 94.11176915,  99.62387832]])

# %% [markdown]
# ### Iterating

# %%
for i in np.nditer(dataset):
    print(i)
# Out:
# 99.14931546
# 104.03852715
# 107.43534677
# 97.85230675
# 98.74986914
# 98.80833412
# 96.81964892
# 98.56783189
# 92.02628776
# 97.10439252
# 99.32066924
# 97.24584816
# 92.9267508
# 92.65657752
# 105.7197853
# 101.23162942
# 95.66253664
# 95.17750125
# 90.93318132
# 110.18889465
# 98.80084371
# 105.95297652
# 98.37481387
# 106.54654286
# 91.37294597
# 100.96781394
# 100.40118279
# 113.42090475
# 105.48508838
# 91.6604946
# 106.1472841
# 95.08715803
# 101.20862522
# 103.5730309
# 100.28690912
# 105.85269352
# 93.37126331
# 108.57980357
# 100.79478953
# 94.20019732
# 102.80387079
# 98.29687616
# 93.24376389
# 97.24130034
# 89.03452725
# 96.2832753
# 104.60344836
# 101.13442416
# 106.71751618
# 102.97585605
# 98.45723272
# 100.72418901
# 106.39798503
# 95.46493436
# 94.35373179
# 106.83273763
# 96.02548256
# 102.82360856
# 106.47551845
# 101.34745901
# 102.45651798
# 98.74767493
# 97.57544275
# 92.5748759
# 105.30350449
# 92.87730812
# 103.19258339
# 104.40518318
# 101.29326772
# ...
