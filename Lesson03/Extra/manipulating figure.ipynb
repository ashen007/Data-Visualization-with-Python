# %% [markdown]
# ## Manipulate Figures

# %%
from matplotlib import image as img
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
photo = img.imread('C:\\Users\\ashen\\Pictures\\bitch\\aabhapaulofficial_44811934_2565349940149311_122320033302605669_n.jpg')
resize = photo[0:900, 0:750]
plt.imshow(resize)

# %% [markdown]
# ### Plotting

# %%
points = ([1,2,13,0,9,12],[8,7,3,6,9,10])
plt.plot(points[0], points[1])

# %%
plt.plot(points[0])

# %%
plt.plot(points[0], points[1],'o')

# %%
canada  = (0.96156,0.99047,1.05584,1.11653,1.23682,1.20679,1.12583,1.25072,1.35809,1.35196,1.21338,1.26457,1.32379,1.22875,1.24492,1.28479,1.30032,1.44933,1.50985,1.505,1.61651,1.35444,1.36876,1.38766,1.43684,1.44948,1.42135,1.38369,1.37388,1.14314)
United_States = (15.38779,15.89158,15.29993,15.87882,17.05914,17.46494,17.24367,18.01708,18.88587,19.10017,19.17742,19.00137,19.15709,19.86225,19.96779,20.14978,21.02473,21.49186,21.72283,21.68023,22.64488,21.94353,21.96475,22.37144,22.60396,22.84073,22.50795,22.77466,22.42597,19.66839)
NA = []
years = [1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009]

for point in range(len(United_States)):
    NA.append(canada[point] + United_States[point])

NA = tuple(NA)

# %%
plt.figure(figsize=(10,10))
plt.plot(NA, 'o', United_States, 'o')
plt.savefig('cola.png', dip=300, bbox_inches='tight')

# %%
cola_data = pd.read_csv('D:\\data visualition\\sample datasets\\coal.csv', index_col='country')

# %%
cola_data
# Out:
#                           1980      1981      1982      1983      1984  \
# country
# North America         16.45179  16.98772  16.47546  17.12407   18.4267
# Bermuda                      0         0         0         0         0
# Canada                 0.96156   0.99047   1.05584   1.11653   1.23682
# Greenland              0.00005   0.00005   0.00003   0.00003   0.00003
# Mexico                 0.10239   0.10562   0.11967   0.12869   0.13071
# ...                        ...       ...       ...       ...       ...
# U.S. Pacific Islands         0         0         0         0         0
# Vanuatu                      0         0         0         0         0
# Vietnam                0.10809   0.10016   0.11204   0.11283   0.11758
# Wake Island                  0         0         0         0         0
# World                  69.8986  71.37043  72.47173  74.54526  79.00603
#
#                           1985      1986      1987      1988      1989  ...  \
# ...

# %%
plt.figure(figsize=[16, 8], dpi=300)
plt.bar(years, United_States, color='#F2CF1D')
plt.bar(years, cola_data.loc['World'],color='#04BF8AB3')
# plt.bar(years, canada, color='#F29F05')
plt.show()

# %%
plt.figure(figsize=[24,12], dpi=300)
x = np.arange(len(years))
width = 0.4

plt.bar(x-width/2, United_States, width=width, color='#D168FF')
plt.bar(x+width/2, cola_data.loc['World'], width=width, color='#6A0DC4')
plt.xticks(x)
ax = plt.gca()
ax.set_xticklabels(years)
plt.show()

# %%
cola_data.columns.values
# Out:
# array(['1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987',
#        '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009'], dtype=object)

# %%
list(cola_data.loc['World'].values)
# Out:
# ['69.8986',
#  '71.37043',
#  '72.47173',
#  '74.54526',
#  '79.00603',
#  '82.36034',
#  '83.66871',
#  '86.36875',
#  '89.08833',
#  '88.92088',
#  '89.09659',
#  '86.00001',
#  '85.0096',
#  '86.21871',
#  '86.95818',
#  '87.87165',
#  '89.28951',
#  '91.69516',
#  '90.1217',
#  '90.41995',
#  '92.28221',
#  '93.03532',
#  '98.05234',
#  '106.54211',
#  '118.00493',
#  '122.54963',
#  '127.04573',
#  '132.78206',
#  '138.82977',
#  '137.33852']
